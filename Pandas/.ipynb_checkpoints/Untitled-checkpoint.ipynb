# %%
# Pandas Series
# Series is a one dimensional array capable of holding data type. The axis labels are Collectively called as Index

# %%
# Creating Series

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {1:10, 2:20, 3:30}

# %%
pd.Series(my_list, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
# Combining Series is DataFrame 
# Creating a DataFrame 
data = {
    'Name': ['John','Anna', 'Peter', 'Linda'],
    'Age': [28,34,29,42],
    'City': ['New York', 'Paris', 'Berlin', 'London'], 
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John',28,'New York', 65000],
    ['Anna',34,'Paris',70000],
    ['Peter', 29, 'Berlin', 62000], 
    ['Linda', 42,'London', 85000]
    ]
df2 = pd.DataFrame(data_list)
columns = ['Name', 'Age', 'City', 'Salary']
df2 = pd.DataFrame(data_list, columns=columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2['City']
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
df2[['Name','City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
# Creating a new Column
df2['Designation'] = ['Doctor', 'Engineer', 'Doctor', 'Engineer']

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000    Engineer

# %%
# Removing Column
df2.drop('Designation', axis=1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000    Engineer

# %%
df2.drop('Designation', axis=1, inplace=True)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.drop(['Age', 'City'], axis=1)
# Out:
#     Name  Salary
# 0   John   65000
# 1   Anna   70000
# 2  Peter   62000
# 3  Linda   85000

# %%
df2.drop(0, axis=0) # Axis value is Default to true
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %%
# Selecting a row
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %%
# Selecting a Subset of DataFrame
df.loc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df.loc[[2,3]][['Name','Age']]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %%
# Conditional Selection
df2[df2['Age']>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
df2[(df2['Age']>30) & (df2['City'] == 'Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000

# %%
# Finding Missing Data
data = {
    'A': [1,2,np.nan,4,5],
    'B': [1,2,3,4,5],
    'C': [1,2,3,np.nan,np.nan],
    'D': [1,np.nan,np.nan,np.nan,5],
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B    C    D
# 0  1.0  NaN  1.0  1.0
# 1  2.0  2.0  2.0  NaN
# 2  NaN  3.0  3.0  NaN
# 3  4.0  4.0  NaN  NaN
# 4  5.0  5.0  NaN  5.0

# %%
df.isna().sum()
# Out:
# A    1
# B    1
# C    2
# D    3
# dtype: int64

# %%
df.isna().any()
# Out:
# A    True
# B    True
# C    True
# D    True
# dtype: bool

# %%
 # Removing Missing Data 
df.dropna()
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
df.dropna(thresh=1)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
# Filling Missing Data 
df.fillna(0)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  0.0
# 2  0.0  3  3.0  0.0
# 3  4.0  4  0.0  0.0
# 4  5.0  5  0.0  5.0

# %%
values = {'A': 10, 'B':20, 'C':30,'D':40}
df.fillna(value=values)
# Out:
#       A  B     C     D
# 0   1.0  1   1.0   1.0
# 1   2.0  2   2.0  40.0
# 2  10.0  3   3.0  40.0
# 3   4.0  4  30.0  40.0
# 4   5.0  5  30.0   5.0

# %%
df.fillna(df.mean())
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  3.0
# 2  3.0  3  3.0  3.0
# 3  4.0  4  2.0  3.0
# 4  5.0  5  2.0  5.0

# %%
# Merging 2 DataFrames

# %%
employees = pd.DataFrame({
    'employee_id': [1, 2, 3, 4, 5],
    'name': ['John', 'Anna', 'Peter', 'Linda', 'Bob'],
    'department': ['HR', 'IT', 'Finance', 'IT', 'HR']
})

# DataFrame 2: Salary information
salaries = pd.DataFrame({
    'employee_id': [1, 2, 3, 6, 7],
    'salary': [60000, 80000, 65000, 70000, 90000],
    'bonus': [5000, 10000, 7000, 8000, 12000]
})

# %%
employees
# Out:
#    employee_id   name department
# 0            1   John         HR
# 1            2   Anna         IT
# 2            3  Peter    Finance
# 3            4  Linda         IT
# 4            5    Bob         HR

# %%
salaries
# Out:
#    employee_id  salary  bonus
# 0            1   60000   5000
# 1            2   80000  10000
# 2            3   65000   7000
# 3            6   70000   8000
# 4            7   90000  12000

# %%
pd.merge(employees, salaries, on='employee_id',how='inner')
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000

# %%
pd.merge(employees, salaries, on='employee_id',how='outer')
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN
# 5            6    NaN        NaN  70000.0   8000.0
# 6            7    NaN        NaN  90000.0  12000.0

# %%
pd.merge(employees, salaries, on='employee_id',how='left')
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN

# %%
pd.merge(employees, salaries, on='employee_id',how='right')
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000
# 3            6    NaN        NaN   70000   8000
# 4            7    NaN        NaN   90000  12000

# %%
# Concatination of 3 DataFrames 
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2'],
    'C': ['C0', 'C1', 'C2']
})

df2 = pd.DataFrame({
    'A': ['A3', 'A4', 'A5'],
    'B': ['B3', 'B4', 'B5'],
    'C': ['C3', 'C4', 'C5']
})

# %%
df1
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2

# %%
df2
# Out:
#     A   B   C
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
pd.concat([df1,df2])
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
pd.concat([df2,df1])
# Out:
#     A   B   C
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2

# %%
pd.concat([df1,df2], axis=1)
# Out:
#     A   B   C   A   B   C
# 0  A0  B0  C0  A3  B3  C3
# 1  A1  B1  C1  A4  B4  C4
# 2  A2  B2  C2  A5  B5  C5

# %%
# Joining DataFrames 
df1 = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie']
}, index=[1, 2, 3])

# Second DataFrame
df2 = pd.DataFrame({
    'score': [85, 90, 75]
}, index=[2, 3, 4])

# %%
df1
# Out:
#       name
# 1    Alice
# 2      Bob
# 3  Charlie

# %%
df2
# Out:
#    score
# 2     85
# 3     90
# 4     75

# %%
df1.join(df2, how='outer')
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0
# 4      NaN   75.0

# %%
df2.join(df1, how='outer')
# Out:
#    score     name
# 1    NaN    Alice
# 2   85.0      Bob
# 3   90.0  Charlie
# 4   75.0      NaN

# %%
# GroupBy 
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
# Group By Category and calculate the sum of sales 
cat = df.groupby('Category')['Sales'].sum()
cat
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
cat = df.groupby('Store')['Sales'].sum()
cat
# Out:
# Store
# S1    720
# S2    780
# Name: Sales, dtype: int64

# %%
# Group by multiple Columns 
cat = df.groupby(['Category','Store'])['Sales'].sum()
cat
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %%
# Aggregation 
df['Sales'].mean()
# Sum, Mean, Median, Min, Max, Count, Std
# Out:
# np.float64(187.5)

# %%
df['Sales'].agg(['sum', 'mean', 'min', 'max', 'count', 'std', 'median'])
# Out:
# sum       1500.000000
# mean       187.500000
# min        100.000000
# max        300.000000
# count        8.000000
# std         66.062741
# median     190.000000
# Name: Sales, dtype: float64

# %%
# Pivot Tables 
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    389     21   John  January      Q1
# 1  2023-01-02       B   West    881     52   Mary  January      Q1
# 2  2023-01-03       C  North    651     53    Bob  January      Q1
# 3  2023-01-04       D  South    542     32  Alice  January      Q1
# 4  2023-01-05       A   East    560     14   John  January      Q1
# 5  2023-01-06       B   West    518     65   Mary  January      Q1
# 6  2023-01-07       C  North    674     12    Bob  January      Q1
# 7  2023-01-08       D  South    806     50  Alice  January      Q1
# 8  2023-01-09       A   East    361     97   John  January      Q1
# 9  2023-01-10       B   West    569     98   Mary  January      Q1
# 10 2023-01-11       C  North    439     67    Bob  January      Q1
# 11 2023-01-12       D  South    721     46  Alice  January      Q1
# 12 2023-01-13       A   East    640     70   John  January      Q1
# 13 2023-01-14       B   West    568     33   Mary  January      Q1
# 14 2023-01-15       C  North    566     80    Bob  January      Q1
# 15 2023-01-16       D  South    390     59  Alice  January      Q1
# 16 2023-01-17       A   East    240     39   John  January      Q1
# 17 2023-01-18       B   West    856     35   Mary  January      Q1
# 18 2023-01-19       C  North    835     42    Bob  January      Q1
# 19 2023-01-20       D  South    483     22  Alice  January      Q1

# %%
pd.pivot_table(df,values='Sales', index='Region', columns='Product', aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     389.0    NaN    NaN    NaN
# North      NaN    NaN  651.0    NaN
# South      NaN    NaN    NaN  542.0
# West       NaN  569.0    NaN    NaN

# %%
pd.pivot_table(df,values=['Sales', 'Units'], index='Region', columns='Product')
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     438.0    NaN    NaN    NaN  48.2   NaN   NaN   NaN
# North      NaN    NaN  633.0    NaN   NaN   NaN  50.8   NaN
# South      NaN    NaN    NaN  588.4   NaN   NaN   NaN  41.8
# West       NaN  678.4    NaN    NaN   NaN  56.6   NaN   NaN

# %%
# Cross Tab 
pd.crosstab(df['Region'], df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %%
# DataFrames Basic Operation 
df1 = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})

# %%
df1.shape
# Out:
# (5, 3)

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df1.describe()
# Out:
#               A          B           C
# count  5.000000   5.000000    5.000000
# mean   3.000000  30.000000  300.000000
# std    1.581139  15.811388  158.113883
# min    1.000000  10.000000  100.000000
# 25%    2.000000  20.000000  200.000000
# 50%    3.000000  30.000000  300.000000
# 75%    4.000000  40.000000  400.000000
# max    5.000000  50.000000  500.000000

# %%
df1['A'] + 10
# Out:
# 0    11
# 1    12
# 2    13
# 3    14
# 4    15
# Name: A, dtype: int64

# %%
def square(x):
    return x**2

# %%
df1['D'] = df1['B'].apply(square)
# Alternate Solution 
# df1['D'] = df1['B'].apply(lambda x : x**2)

# %%
df1
# Out:
#    A     B    C        D
# 0  1   100  100    10000
# 1  2   400  200   160000
# 2  3   900  300   810000
# 3  4  1600  400  2560000
# 4  5  2500  500  6250000

# %%
# Feature Extraction Project

# %%
df = pd.read_csv(r'anime.csv')
df.head()
# Out:
#    Rank                                              Title  Score
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05

# %%
df.loc[1]
# Out:
# Rank                                                     2
# Title    Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...
# Score                                                 9.07
# Name: 1, dtype: object

# %%
df.loc[2]['Title']
# New Column for Episode Count
# Out:
# 'Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members'

# %%
def extract_episodes(txt): 
    check = False 
    data = ""
    for i in txt:
        if i == ')':
            check = False
            return data
        if check == True:
            data = data + i
        if i == '(':
            check = True

# %%
df['Episodes'] = df['Title'].apply(extract_episodes)

# %%
df['Episodes'] = df['Episodes'].str.replace(' eps','')

# %%
df['Episodes'] = df['Episodes'].astype(int)

# %%
# New Column for time stamp

# %%
def extraction_time(txt):
    tp = ""
    for i in range(len(txt)):
        if txt[i] == ')':
            for j in range(i + 1, i + 20):
                tp += txt[j]
            return tp

# %%
df['Total_Time'] = df['Title'].apply(extraction_time)

# %%
df.head()
# Out:
#    Rank                                              Title  Score episodes  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10       64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07       24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06       13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06       51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05       10
#
#    Episodes Time_Stamp           Total_Time Months
# 0        64       None  Apr 2009 - Jul 2010   None
# 1        24       None  Apr 2011 - Sep 2011   None
# 2        13       None  Oct 2022 - Dec 2022   None
# 3        51       None  Apr 2015 - Mar 2016   None
# 4        10       None  Apr 2019 - Jul 2019   None

# %%
from dateutil.relativedelta import relativedelta
from datetime import datetime

def calculate_total_months(period):
    try:
        start_str, end_str = period.split(' - ')
        start_date = datetime.strptime(start_str, '%b %Y')
        end_date = datetime.strptime(end_str, '%b %Y')
        r = relativedelta(end_date, start_date)
        return r.years * 12 + r.months + 1  # +1 to include the starting month
    except:
        return None

df['Months'] = df['Total_Time'].apply(calculate_total_months)

# %%
df
# Out:
#     Rank                                              Title  Score episodes  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10       64
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07       24
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06       13
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06       51
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05       10
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04       51
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04        1
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04      148
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04       13
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03       13
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03        2
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02      110
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99       13
# 13    14  Fruits Basket: The FinalTV (13 eps)Apr 2021 - ...   8.99       13
# 14    15  Gintama.TV (12 eps)Jan 2017 - Mar 2017302,232 ...   8.98       12
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...   8.94      201
# 16    17  Koe no KatachiMovie (1 eps)Sep 2016 - Sep 2016...   8.94        1
# 17    18  3-gatsu no Lion 2nd SeasonTV (22 eps)Oct 2017 ...   8.93       22
# 18    19  Clannad: After StoryTV (24 eps)Oct 2008 - Mar ...   8.93       24
# 19    20  Code Geass: Hangyaku no Lelouch R2TV (25 eps)A...   8.91       25
# 20    21  Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...   8.91        1
# 21    22  Violet Evergarden MovieMovie (1 eps)Sep 2020 -...   8.89        1
# 22    23  Owarimonogatari 2nd SeasonTV (7 eps)Aug 2017 -...   8.88        7
# 23    24  Gintama.: Shirogane no Tamashii-hen - Kouhan-s...   8.88       14
# 24    25  MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...   8.87       74
# 25    26  Kimi no Na wa.Movie (1 eps)Aug 2016 - Aug 2016...   8.84        1
# 18        24       None  Oct 2008 - Mar 2009       6
# 19        25       None  Apr 2008 - Sep 2008       6
# 20         1       None  Jul 2013 - Jul 2013       1
# 21         1       None  Sep 2020 - Sep 2020       1
# 22         7       None  Aug 2017 - Aug 2017       1
# 23        14       None  Jul 2018 - Oct 2018       4
# 24        74       None  Apr 2004 - Sep 2005      18
# 25         1       None  Aug 2016 - Aug 2016       1
# 26         1       None  Dec 2022 - Dec 2022       1
# 27        12       None  Oct 2022 - Dec 2022       3
# 28         1       None  Dec 2022 - Dec 2022       1
# 29        24       None  Jan 2023 - Jun 2023       6
# 30        23       None  Jul 2023 - Aug 2023       2
# 31        12       None  Jan 2018 - Mar 2018       3
# 32        26       None  Apr 2020 - Oct 2021      19
# 33        13       None  Jan 2019 - Apr 2019       4
# 34        16       None  Dec 2020 - Mar 2021       4
# 35        11       None  Dec 2021 - Feb 2022       3
# 36         1       None  Jan 2017 - Jan 2017       1
# 37        11       None  Apr 2023 - Jun 2023       3
# 38        10       None  Oct 2016 - Dec 2016       3
# 39         1       None  Jul 2001 - Jul 2001       1
# 40        26       None  Jul 2013 - Dec 2013       6
# 41        12       None  Jan 2022 - Apr 2022       4
# 42        75       None  Oct 2000 - Mar 2002      18
# 43        26       None  Apr 1998 - Apr 1999      13
# 44        26       None  Apr 2022 - Oct 2022       7
# 45        24       None  Jul 2019 - Dec 2019       6
# 46        10       None  Oct 2014 - Dec 2014       3
# 47        12       None  Jan 2017 - Mar 2017       3
# 48        12       None  Oct 2022 - Dec 2022       3
# 49         4       None  Feb 1999 - Sep 1999       8

# %%
# Which Anime has the highest score 
df[df['Score'] == df['Score'].max()]['Title']
# Out:
# 0    Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# Name: Title, dtype: object

# %%
# Top 5 Highest Scoring Anime 
df['Title'].head()
# Out:
# 0    Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# 1    Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...
# 2    Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...
# 3    Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...
# 4    Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...
# Name: Title, dtype: object

# %%
# Anime with the highest episode count 
df[df['Episodes'] == df['Episodes'].max()]
# Out:
#     Rank                                              Title  Score episodes  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...   8.94      201
#
#     Episodes Time_Stamp           Total_Time  Months
# 15       201       None  Apr 2006 - Mar 2010      48

# %%
# Top 5 Highest Episode Count
df['Episodes'].nlargest(5)
# Out:
# 15    201
# 7     148
# 11    110
# 42     75
# 24     74
# Name: Episodes, dtype: int64

# %%
# Anime with the highest running count 
df[df['Months'] == df['Months'].max()]
# Out:
#     Rank                                              Title  Score episodes  \
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02      110
#
#     Episodes Time_Stamp           Total_Time  Months
# 11       110       None  Jan 1988 - Mar 1997     111
